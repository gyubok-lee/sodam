# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import tqdm

import urllib.request
from konlpy.tag import Okt
from gensim.models.word2vec import Word2Vec
import pandas as pd
import matplotlib.pyplot as plt
from konlpy.tag import Twitter

from sklearn.cluster import KMeans
from ast import literal_eval
import numpy as np
from PIL import Image
# %matplotlib inline

# %%
ssodam = pd.read_csv('서담_8월업데이트.txt', sep = '|', index_col = 0)
ssodam = ssodam.astype( {'comment_num' : int, 'like': int, 'view' : int, 'dislike' : int })
ssodam
# Out:
#                                      title header  comment_num writer  like  \
# 0               도대체가 학교의 기준이 무엇인지 이해가 안됩니다    NaN           14     익명    32
# 1     학교 시설물 관련 부서 전화번호 적을테니 내일부터 전화 한통씩하자    NaN           10     익명    38
# 2                           걍 서강사이버대학으로 하자    NaN           10     익명    42
# 3                                학교 너무 빡친다     쉐복           54     익명   106
# 4                       박미선 누님 결혼식날 비 오셨죠?    NaN            2     익명    40
# ...                                    ...    ...          ...    ...   ...
# 8214                            새해맞이 연게 첫글    NaN            5     익명    35
# 8215                            올해는 행시합격한다    NaN            5     익명    86
# 8216                     ??? : 야 올해가 몇년이냐?    NaN            9     익명   127
# 8217                        2020년 서강의 첫 모습    NaN            5     익명   101
# 8218                           2020년 파이팅!!    NaN           15     익명   168
#
#      upload_date  view                                               link  \
# 0          46분 전   429  http://www.ssodam.com//content/980179?prev=1&p...
# 1          48분 전   577  http://www.ssodam.com//content/980177?prev=1&p...
# 2          55분 전   564  http://www.ssodam.com//content/980173?prev=1&p...
# 3          18:24  1830  http://www.ssodam.com//content/980162?prev=1&p...
# 4          17:44   824  http://www.ssodam.com//content/980129?prev=1&p...
# ...          ...   ...                                                ...
# 8214       01/01   785  http://www.ssodam.com//content/813081?prev=245...
# 8215       01/01  1180  http://www.ssodam.com//content/813062?prev=245...
# 8216       01/01  1982  http://www.ssodam.com//content/813058?prev=245...
# 8217       01/01  1931  http://www.ssodam.com//content/813047?prev=245...
# 8218       01/01  1335  http://www.ssodam.com//content/813032?prev=245...
#
#       borad                                               text  dislike  \
# 0       CPA  교육부 방역수칙이 도대체 어떤 점에서 어떻게 미달이 되는데요? 이걸 알려주셔야죠미달...        0
# 1       익게2  코로나 이후로 전화 자주하는편인데 나도 처음에 어디로 전화해야할지도 막막하고 그래서...        3
# 2       익게2  학교 부지는 외부인 등산하게 냅두고운동장 농구장은 외부인들한테 24시간 무료개방하고...        7
# 3       익게2  다른 학교는 감염 위험이 없어서 시설 개방하는 줄 아냐? 아니 등록금은 다 쳐받아놓...       13
# 4       익게2                                 마지막 ㅋ 하나 붙인게 킬포ㅋㅋㅋ        1
# ...     ...                                                ...      ...
# 8214  연애상담소                                다들 올해는  인생의 단짝을 만나용        0
# 8215    익게2  토모관 여러분도\n\n\n            \n\n            \n  ...        0
# 8216    익게2                                            다들 새해복!        0
# 8217    익게2  방금 토모관에서 나와서 찍어봤어20대의 절반을 서강과 함께할수 있어서 진심으로 행복...        0
# 8218    익게2                                          모두들 파이팅!!        0
#
#                                                 comment            date_time  \
# 0     [['근데 아직 확정?은 아니지 않나요 아직까지는 그냥 누군가가 그렇다더라니까 기다...  2020-08-13 19:01:00
# 1     [['저런 곳보다 대책회의쪽이 더 확실할텐데 총학도 회의에 몇번 참관한걸로 아는데 ...  2020-08-13 18:59:00
# 2     [['그만•••'], ['뭘 그만하라는거야?'], ['이런 댓글이야 말로 그만......  2020-08-13 18:52:00
# 3     [['교육부 지침에 안맞으면 못여는건가?'], ['어떻게 다른대학들은 5~6월에 고...  2020-08-13 18:24:00
# 4     [['난 오셨다길래 정지훈 얘기하는 줄'], ['??? : 모르는데 어떻게가요'],...  2020-08-13 17:44:00
# ...                                                 ...                  ...
# 8214  [['네에 ㅠㅠ 올해는 정말 행복하고 싶어요.. 님두 좋은 인연 만나서 행복하세요 ...  2020-01-01 00:24:00
# 8215  [['나도 행시 올 해 붙는다!'], ['나도 올해 붙는다!'], ['민특상디 사례...  2020-01-01 00:08:00
# 8216  [['좌우로 정렬해주세여'], ['ㅁㅊ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 적절한 짤 추'], ['...  2020-01-01 00:06:00
# 8217  [['나도 방금 나왔는데 ㅎㅎㅎ 다미 본듯'], ['내년에는 좋은 소식만 들리자!!...  2020-01-01 00:04:00
# 8218  [['올 첫글 ㅋㅋ'], ['아 너 뭔데 나보다 일찍 썼냐ㅡㅡ추천이나 먹어라'], ...  2020-01-01 00:00:00
#
#       hour                                         word_token
# 0     19.0  [('도대체', 'Noun'), ('가', 'Josa'), ('학교', 'Noun'...
# 1     18.0  [('학교', 'Noun'), ('시설', 'Noun'), ('물', 'Noun')...
# 2     18.0  [('걍', 'Adverb'), ('서강', 'Noun'), ('사이버', 'Nou...
# 3     18.0  [('학교', 'Noun'), ('너무', 'Adverb'), ('빡친다', 'Ad...
# 4     17.0  [('박미선', 'Noun'), ('누님', 'Noun'), ('결혼식', 'Nou...
# ...    ...                                                ...
# 8214   0.0  [('새해', 'Noun'), ('맞이', 'Noun'), ('연', 'Noun')...
# 8215   0.0  [('올해', 'Noun'), ('는', 'Josa'), ('행시', 'Noun')...
# 8216   0.0  [('???', 'Punctuation'), (':', 'Punctuation'),...
# 8217   0.0  [('2020년', 'Number'), ('서강', 'Noun'), ('의', 'J...
# 8218   0.0  [('2020년', 'Number'), ('파이팅', 'Noun'), ('!!', ...
#
# [8219 rows x 15 columns]

# %%
tmpp = pd.DataFrame()
tmpp['tmp'] = ssodam['text']
tmpp = tmpp.fillna('NaN')
ssodam['text'] = tmpp['tmp']

for i in ssodam.index:
    if ssodam['text'][i] == 'NaN':
        ssodam['text'][i] = ssodam['title'][i]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ssodam['text'] = ssodam['text'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣, \d, % ]","")
ssodam
# Out:
#                                      title header  comment_num writer  like  \
# 0               도대체가 학교의 기준이 무엇인지 이해가 안됩니다    NaN           14     익명    32
# 1     학교 시설물 관련 부서 전화번호 적을테니 내일부터 전화 한통씩하자    NaN           10     익명    38
# 2                           걍 서강사이버대학으로 하자    NaN           10     익명    42
# 3                                학교 너무 빡친다     쉐복           54     익명   106
# 4                       박미선 누님 결혼식날 비 오셨죠?    NaN            2     익명    40
# ...                                    ...    ...          ...    ...   ...
# 8214                            새해맞이 연게 첫글    NaN            5     익명    35
# 8215                            올해는 행시합격한다    NaN            5     익명    86
# 8216                     ??? : 야 올해가 몇년이냐?    NaN            9     익명   127
# 8217                        2020년 서강의 첫 모습    NaN            5     익명   101
# 8218                           2020년 파이팅!!    NaN           15     익명   168
#
#      upload_date  view                                               link  \
# 0          46분 전   429  http://www.ssodam.com//content/980179?prev=1&p...
# 1          48분 전   577  http://www.ssodam.com//content/980177?prev=1&p...
# 2          55분 전   564  http://www.ssodam.com//content/980173?prev=1&p...
# 3          18:24  1830  http://www.ssodam.com//content/980162?prev=1&p...
# 4          17:44   824  http://www.ssodam.com//content/980129?prev=1&p...
# ...          ...   ...                                                ...
# 8214       01/01   785  http://www.ssodam.com//content/813081?prev=245...
# 8215       01/01  1180  http://www.ssodam.com//content/813062?prev=245...
# 8216       01/01  1982  http://www.ssodam.com//content/813058?prev=245...
# 8217       01/01  1931  http://www.ssodam.com//content/813047?prev=245...
# 8218       01/01  1335  http://www.ssodam.com//content/813032?prev=245...
#
#       borad                                               text  dislike  \
# 0       CPA  교육부 방역수칙이 도대체 어떤 점에서 어떻게 미달이 되는데요 이걸 알려주셔야죠미달이...        0
# 1       익게2  코로나 이후로 전화 자주하는편인데 나도 처음에 어디로 전화해야할지도 막막하고 그래서...        3
# 2       익게2  학교 부지는 외부인 등산하게 냅두고운동장 농구장은 외부인들한테 24시간 무료개방하고...        7
# 3       익게2  다른 학교는 감염 위험이 없어서 시설 개방하는 줄 아냐 아니 등록금은 다 쳐받아놓고...       13
# 4       익게2                                 마지막 ㅋ 하나 붙인게 킬포ㅋㅋㅋ        1
# ...     ...                                                ...      ...
# 8214  연애상담소                                 다들 올해는 인생의 단짝을 만나용        0
# 8215    익게2  토모관 여러분도                                토모관 밖 ...        0
# 8216    익게2                                             다들 새해복        0
# 8217    익게2  방금 토모관에서 나와서 찍어봤어20대의 절반을 서강과 함께할수 있어서 진심으로 행복...        0
# 8218    익게2                                            모두들 파이팅        0
#
#                                                 comment            date_time  \
# 0     [['근데 아직 확정?은 아니지 않나요 아직까지는 그냥 누군가가 그렇다더라니까 기다...  2020-08-13 19:01:00
# 1     [['저런 곳보다 대책회의쪽이 더 확실할텐데 총학도 회의에 몇번 참관한걸로 아는데 ...  2020-08-13 18:59:00
# 2     [['그만•••'], ['뭘 그만하라는거야?'], ['이런 댓글이야 말로 그만......  2020-08-13 18:52:00
# 3     [['교육부 지침에 안맞으면 못여는건가?'], ['어떻게 다른대학들은 5~6월에 고...  2020-08-13 18:24:00
# 4     [['난 오셨다길래 정지훈 얘기하는 줄'], ['??? : 모르는데 어떻게가요'],...  2020-08-13 17:44:00
# ...                                                 ...                  ...
# 8214  [['네에 ㅠㅠ 올해는 정말 행복하고 싶어요.. 님두 좋은 인연 만나서 행복하세요 ...  2020-01-01 00:24:00
# 8215  [['나도 행시 올 해 붙는다!'], ['나도 올해 붙는다!'], ['민특상디 사례...  2020-01-01 00:08:00
# 8216  [['좌우로 정렬해주세여'], ['ㅁㅊ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 적절한 짤 추'], ['...  2020-01-01 00:06:00
# 8217  [['나도 방금 나왔는데 ㅎㅎㅎ 다미 본듯'], ['내년에는 좋은 소식만 들리자!!...  2020-01-01 00:04:00
# 8218  [['올 첫글 ㅋㅋ'], ['아 너 뭔데 나보다 일찍 썼냐ㅡㅡ추천이나 먹어라'], ...  2020-01-01 00:00:00
#
#       hour                                         word_token
# 0     19.0  [('도대체', 'Noun'), ('가', 'Josa'), ('학교', 'Noun'...
# 1     18.0  [('학교', 'Noun'), ('시설', 'Noun'), ('물', 'Noun')...
# 2     18.0  [('걍', 'Adverb'), ('서강', 'Noun'), ('사이버', 'Nou...
# 3     18.0  [('학교', 'Noun'), ('너무', 'Adverb'), ('빡친다', 'Ad...
# 4     17.0  [('박미선', 'Noun'), ('누님', 'Noun'), ('결혼식', 'Nou...
# ...    ...                                                ...
# 8214   0.0  [('새해', 'Noun'), ('맞이', 'Noun'), ('연', 'Noun')...
# 8215   0.0  [('올해', 'Noun'), ('는', 'Josa'), ('행시', 'Noun')...
# 8216   0.0  [('???', 'Punctuation'), (':', 'Punctuation'),...
# 8217   0.0  [('2020년', 'Number'), ('서강', 'Noun'), ('의', 'J...
# 8218   0.0  [('2020년', 'Number'), ('파이팅', 'Noun'), ('!!', ...
#
# [8219 rows x 15 columns]

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','하다','ㅋ']

# %%
okt = Okt()
t = Twitter()
tokenized_data = []
for sentence in tqdm.tqdm_notebook(ssodam['text']):
    temp_X = t.nouns(sentence) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    tokenized_data.append(temp_X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=8219.0), HTML(value='')))

# %%
w2v_model = Word2Vec(sentences = tokenized_data, min_count = 30, size = 100, window = 5, sg = 1, workers = 4)
w2v_model.save("w1.model")

# %%
w2v_model.most_similar('코로나')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('사태', 0.8399101495742798),
#  ('신종', 0.774043619632721),
#  ('확산', 0.7352579832077026),
#  ('시국', 0.7310693264007568),
#  ('폐렴', 0.7290308475494385),
#  ('바이러스', 0.7227926254272461),
#  ('유럽', 0.7172774076461792),
#  ('초기', 0.710247278213501),
#  ('졸업식', 0.7044838070869446),
#  ('취소', 0.701439619064331)]

# %%
word_vectors = w2v_model.wv.syn0
w2v_model.wv.syn0.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
# (1882, 100)

# %%
# K-means 시각화 파트

num_clusters = 20 #cluster의 갯수 산정
kmeans_clustering = KMeans( n_clusters = num_clusters, random_state = 2020, max_iter = 500)

# %%
idx = kmeans_clustering.fit_predict(word_vectors)

# %%
idx = list(idx)
names = w2v_model.wv.index2word 
word_centroid_map = {names[i]: idx[i] for i in range(len(names))}

# %% [markdown]
# - 2 : 불만 / 요구사항
# - 10 + 17 :교내이슈
# - 3 : 고시
# - 5 + 12 : 인간관계
# - 6 + 9 + 16 : 취업
# - 7 : 커뮤니티
# - 8 : 맛게
# - 11 : 대학평가
# - 13 : 가치관
# - 15 : 정치 / 사회
# - 19 : 코로나
# - 0 1 4 14 18 : 애매

# %%
for cluster in range(0,num_clusters):
    # 클러스터 번호를 출력
    print("\nCluster {}".format(cluster))
    
    # 클러스터번호와 클러스터에 있는 단어를 찍는다.
    words = []
    for i in range(0,len(list(word_centroid_map.values()))): #list(dict)키 값만 리스트로 반환
        if len(list(word_centroid_map.keys())[i]) == 1:
            continue
        #list(dict.values)는 value값이 리스트로 반환
        if( list(word_centroid_map.values())[i] == cluster ):
            words.append(list(word_centroid_map.keys())[i])
    print(words)
# Out:
# Cluster 0
# ['오늘', '다시', '연락', '갑자기', '혼자', '하루', '카톡', '동생', '전화', '매일', '알바', '어제', '선생님', '아침', '저녁', '새벽', '주말', '언니', '번호', '방금', '일주일', '내일', '문자', '자취', '약속', '자고', '종일', '잠깐', '생일', '출근', '며칠', '저번', '데이트', '겨우', '답장', '점심', '퇴근', '그날', '일찍', '핸드폰', '독서실', '이틀', '몰래', '도착', '안보', '차단', '통화', '용돈', '편지', '이불', '고시생', '일어나서', '생리']
#
# Cluster 1
# ['진짜', '그냥', '지금', '하나', '보고', '사실', '계속', '이제', '여기', '요즘', '일단', '해도', '어디', '무슨', '원래', '입장', '거기', '이건', '제대로', '그게', '달라', '이름', '누구', '그거', '누가', '등등', '아무', '심지어', '아예', '예전', '잘못', '자꾸', '언제', '수가', '가면', '반응', '제발', '완전', '대체', '인간', '굳이', '고생', '점점', '중이', '하자', '저런', '위로', '충격', '당장', '사과', '애초', '끼리', '는걸', '자랑', '거지', '보이', '영화', '막상', '옛날', '화가', '무시', '사정', '기적', '벌써', '가야', '어쨌든', '목소리', '안해', '시국', '자연', '거임', '회장', '난리', '자유', '요새', '레전드', '저기', '마냥', '가도', '칭찬', '오지', '몇몇', '거래', '어이', '오해', '가요', '자살', '싸움', '보임', '게다가', '쓰레기', '된거', '드립', '사기', '대하', '도대체', '발언', '본적', '감독', '바보', '가까이', '반박', '동물', '고함', '온갖', '정작', '듣기', '너희', '기대', '처럼', '라며', '이자', '홍대', '군인', '톡방', '연예인', '안함', '한편', '장면', '려고', '우린', '만화', '스압', '그대', '핑계', '남녀', '배우', '조심', '무리', '가해자', '모양', '만하', '일상', '조롱', '어깨', '주인', '양심', '미안']
#
# Cluster 2
# ['관련', '동아리', '현재', '활동', '예정', '사항', '금지', '등록', '총장', '회의', '사태', '학생회', '참여', '제한', '신청', '인원', '이전', '일정', '제공', '조치', '대상', '일부', '취소', '예수회', '제도', '행사', '단체', '기부', '학사', '교내', '대책', '연구', '공식', '안내', '모집', '모임', '총학생회', '대회', '논의', '건의', '여부', '동연', '홈페이지', '기관', '중앙', '담당', '절차', '위원회', '자격', '대위', '변경', '도입', '비상', '언론사', '추후', '제명', '교육부', '규모', '각종', '환불', '원금', '관계자', '소속', '지급', '접수', '교류', '주요', '연세대', '실시', '참석', '재단', '투표', '교직원', '심사', '요건', '구성원', '검토', '본부', '혜택', '이사회', '최초', '주간', '안건', '고려대', '청년', '모금', '현황', '권고', '법인']
#
# Cluster 3
# ['문제', '시험', '점수', '기출', '리트', '방식', '지문', '기본', '중간', '연습', '언어', '집중', '논리', '개념', '강사', '평균', '인강', '객관', '추리', '출제', '정답', '전제', '모의고사', '응시', '범위', '회계', '유형', '풀이', '기초', '교재', '난이도', '이론', '논증', '채점', '퀴즈', '해설', '독해', '베이스', '세법', '순서']
#
# Cluster 4
# ['생각', '공부', '시간', '정말', '처음', '한번', '바로', '조금', '이해', '느낌', '고민', '수도', '기억', '마지막', '항상', '먼저', '별로', '상태', '제일', '크게', '나중', '기도', '역시', '분위기', '평소', '운동', '보기', '나름', '그대로', '거나', '관계', '약간', '일이', '무조건', '신경', '아마', '포기', '대충', '아주', '사고', '편이', '대답', '하정우', '어차피', '후회', '하라', '부담', '당황', '그동안', '멘탈', '게임', '실수', '반복', '초반', '스타일', '부터', '생기', '덕분', '잡고', '마치', '차라리', '살짝', '매번', '화이팅', '시도', '노트북', '여유', '단어', '보지', '인상', '단점', '일도', '하니', '몇개', '워낙', '무난', '금은', '길이', '종종', '잠시', '안나', '그림', '케이스', '상관', '중반', '종이', '치면', '도저히', '속도', '쓰기', '긴장', '수험생', '재미', '최악', '야근', '자극', '눈썹', '습관', '크기', '상식', '남아', '취미', '용기', '포인트', '후반', '보이지', '만족', '만남', '어찌', '인간관계', '구해', '자세', '듯이', '표시', '여태', '진도', '감당', '취향', '체력']
#
# Cluster 5
# ['친구', '자기', '얘기', '마음', '남친', '남자', '여자', '연애', '기분', '그때', '주변', '뭔가', '걱정', '인생', '서로', '사랑', '군대', '결혼', '모습', '머리', '나이', '얼굴', '가끔', '세상', '자주', '순간', '얼마', '대화', '오빠', '성격', '여자친구', '여친', '건가', '남자친구', '가슴', '정신', '눈물', '감정', '누나', '스트레스', '상처', '애가', '진심', '표정', '평생', '외모', '장난', '눈치', '선물', '존나', '다행', '노래', '소개팅', '화장', '몇번', '민희', '직장인', '애인', '추억', '한마디', '만날', '성인', '자존감', '어그', '피부', '만난', '런가', '신입생', '행복', '전역', '적도', '고딩', '살이', '감동', '거짓말', '고통', '어른', '면서', '우울증', '여자애', '주위', '술자리', '한참', '고백', '은근', '다해', '걔네', '이별', '금방', '축하', '문득', '거절', '말투', '짜증', '웃음', '자존심', '커플', '민석', '중학교', '임신', '한텐', '애정', '억지로', '근육', '한숨', '예의', '내면', '볼때', '푸념', '연인', '애교', '강요', '고등학생', '시선', '말로', '전남친', '농담', '단말', '성욕', '전여친']
#
# Cluster 6
# ['지원', '취업', '회사', '경험', '기업', '인턴', '사업', '직무', '채용', '교육', '업무', '저희', '인사', '변호사', '시장', '근무', '기술', '직장', '분야', '투자', '문화', '스펙', '학회', '금융', '신입', '전략', '대기업', '입사', '해외', '프로그램', '공무원', '역량', '연봉', '자격증', '과장', '삼성', '영업', '공기업', '프로젝트', '경력', '산업', '부서', '취지', '외국', '개발', '인재', '상품', '희망', '현직', '이직', '전환', '중고', '커리어', '주식', '하반기', '보험', '공고', '대외', '전문', '전자', '성향', '조직', '창업', '에너지', '보증', '그룹', '은행', '상반기', '수행', '퇴사', '소재', '중소기업', '기금', '업계', '정규직', '임용', '컨설팅', '네트워크', '신용', '증권']
#
# Cluster 7
# ['다미', '댓글', '정보', '혹시', '참고', '확인', '추가', '해당', '작성', '관심', '정리', '동문', '직접', '게시', '말씀', '의견', '영상', '기사', '후기', '메일', '아래', '답변', '공유', '링크', '유튜브', '인기', '오픈', '게시판', '검색', '인터넷', '상담', '커뮤니티', '서비스', '광고', '홍보', '사이트', '페이지', '문의', '출처', '전달', '지도', '감사', '캡쳐', '부탁', '수정', '삭제', '응원', '익명', '요약', '가입', '구매', '주시', '요청', '제목', '복사', '주로', '파일', '동의', '연결', '안녕', '제작', '커뮤', '주소', '다수', '할인', '판매', '청원', '인증', '회원', '구글', '화면', '유출', '수치', '실시간', '채널', '두번째', '코드', '이메일', '다운', '촬영', '입력', '모델', '블로그', '계정', '와이파이', '클릭', '첨부', '환영', '채팅', '페이스북', '메시지', '이벤트', '드릴', '카카오', '떡밥', '양해', '업데이트']
#
# Cluster 8
# ['사진', '추천', '카페', '가격', '사장', '가게', '근처', '위치', '식당', '제품', '리뷰', '방문', '고양이', '메뉴', '카드', '음식', '신촌', '인스타', '주문', '지인', '커피', '고기', '네이버', '식사', '맛집', '치킨', '코스', '결제', '먹기', '매장', '배달', '브랜드', '버거', '테이블', '위스키', '택배', '재료', '서른', '피자', '입구', '포장', '위생', '사이즈', '세트', '맥주', '치즈', '샐러드', '이대', '한강']
#
# Cluster 9
# ['면접', '준비', '질문', '진행', '합격', '영어', '서류', '스터디', '소개', '발표', '전형', '대비', '자소', '최종', '실무', '소서', '인성', '필기', '논술', '정량', '위주', '토익', '토론', '인적', '합격자', '문항', '임원', '배수', '모의', '적성', '시즌', '탈락', '검찰', '압박', '예비', '외국어', '한국어', '동차']
#
# Cluster 10
# ['교수', '학생', '수업', '학기', '강의', '과목', '학점', '성적', '선택', '전공', '과제', '공지', '학부', '개강', '온라인', '전체', '경영', '부정행위', '제출', '처리', '수강', '대면', '조교', '요구', '등록금', '경제학', '수학', '수강신청', '장학금', '휴학', '필수', '정성', '오프라인', '연기', '행정', '시행', '캠퍼스', '실험', '패논패', '경영학', '비율', '비대', '복전', '논문', '사이버', '연장', '고급', '교양', '패스', '확정', '법학', '족보', '에타', '철학', '동영상', '계절', '개설', '수요', '레포트', '학습', '기말고사', '중간고사', '허용', '복수', '인문', '충족']
#
# Cluster 11
# ['서강대', '대학', '서강', '선배', '생활', '졸업', '학년', '로스쿨', '학우', '서울', '새내기', '올해', '경제', '여러분', '작년', '학번', '동기', '출신', '시기', '입시', '입학', '지방', '고등학교', '학과', '후배', '목표', '진로', '실력', '수능', '취준', '과외', '서울대', '시절', '대학원', '도전', '대학교', '박사', '대학생', '대형', '가기', '학벌', '재수', '연대', '졸업생', '문과', '상위', '재학생', '공대', '성대', '취직', '의대', '행시', '진학', '회계사', '순위', '내년', '편입', '고시', '대학원생', '수험', '진입', '취준생', '고대', '한양대', '유학', '입결', '컴공', '학문', '연고', '이과', '사시', '통계', '정시', '스카이', '원서', '명문']
#
# Cluster 12
# ['우리', '엄마', '아빠', '소리', '부모님', '가족', '거리', '자리', '할머니', '사이', '아버지', '아이', '화장실', '바람', '아파트', '다가', '어머니', '할아버지', '간다', '새끼', '와중', '타고', '동네', '아저씨', '집안', '버스', '상상', '부모', '드라마', '아들', '자식', '다리', '담배', '휴가', '간부', '강아지', '지하철', '냄새', '택시', '예약', '아내', '사서', '가방', '바닥', '물건', '침대', '멀리', '요리', '이모', '나무', '김밥', '초등학교', '편의점', '손님', '장사', '창문', '병사', '청소', '애기', '산책', '부부', '가라', '교장', '고개', '구석', '계단', '마리', '심장', '생활비', '취급', '구경', '선임', '날씨', '감자', '하늘', '친척', '아주머니']
#
# Cluster 13
# ['사람', '때문', '다른', '상황', '대한', '대해', '본인', '이유', '위해', '가지', '가장', '사회', '노력', '이야기', '자신', '자체', '절대', '수준', '대부분', '얼마나', '무엇', '그것', '의미', '매우', '스스로', '라면', '전혀', '능력', '차이', '비교', '결론', '현실', '만약', '오히려', '행동', '기회', '상대', '누군가', '필요', '인정', '존재', '당신', '표현', '피해', '주의', '이면', '최고', '미래', '이기', '상대방', '직업', '인지', '조언', '환경', '유지', '공감', '더욱', '가정', '반대', '목적', '최선', '과거', '영향', '세대', '각자', '방향', '정치', '다그', '마찬가지', '분명', '인식', '만큼', '가치', '건강', '이미지', '태도', '최소한', '변화', '신뢰', '시대', '불만', '중심', '의도', '경쟁', '안정', '매력', '발전', '자신감', '역할', '차별', '의지', '팩트', '불구', '대처', '긍정', '부정', '배려', '의식', '과연', '공격', '설득', '혼란', '역사', '극복', '서도', '종교', '특성', '존중', '대가', '소득', '마인드', '비난', '확신', '성공', '보상', '소위', '대다수', '법조인', '진정', '사람과', '아웃', '일지', '기여', '특징', '대우', '작품', '나은', '계기', '대의', '가치관', '것임', '심리', '보수', '갈등', '희생', '성경']
#
# Cluster 14
# ['책임', '법적', '위반', '탈퇴', '침해', '저작권', '출시', '영구', '개인정보보호법']
#
# Cluster 15
# ['한국', '당시', '최근', '사건', '관리', '미국', '신천지', '정부', '직원', '가능성', '국가', '우리나라', '대표', '의사', '나라', '신고', '여성', '해커', '주장', '세계', '발견', '시스템', '피해자', '뉴스', '논란', '한국인', '강제', '내부', '국제', '정의', '명의', '대응', '의심', '계약', '언론', '비판', '위안부', '이하', '업체', '의문', '조건', '보장', '처벌', '국민', '체크', '차원', '금액', '위기', '두기', '대한민국', '신부', '대만', '집단', '홍콩', '자제', '영국', '시민', '외국인', '행위', '지속', '기자', '글로벌', '강남', '시위', '보도', '로부터', '합의', '지적', '우려', '단지', '원인', '인권', '부동산', '정책', '중인', '해고', '이사', '유럽', '위험', '장기', '자녀', '제안', '고객', '집주인', '초기', '생산', '방지', '사무', '지지', '보호', '유학생', '동료', '설치', '감시', '강도', '전파', '거부', '복지', '부자', '전세', '폭행', '근로자', '수사', '거주', '무단', '전쟁', '여론', '증거', '입자', '혐의', '비행기', '현대']
#
# Cluster 16
# ['경우', '내용', '도움', '모든', '부분', '개인', '결과', '실제', '과정', '방법', '설명', '통해', '기준', '결정', '평가', '또한', '자료', '여러', '미리', '해결', '일반', '공개', '우선', '주제', '최대한', '계획', '고려', '다만', '판단', '사례', '제외', '분석', '따라서', '활용', '예상', '파악', '단계', '계산', '지식', '기존', '구성', '적용', '장점', '특정', '규정', '적극', '구조', '반영', '피드백', '로서', '보시', '기타', '효과', '근거', '요소', '방안', '주관', '제시', '구체', '형식', '통과', '달리', '언급', '한계', '보고서', '설정', '전반', '기능', '현장', '개선', '데이터', '어려움', '핵심', '디자인', '각각', '성과', '테스트', '마련', '영역', '바탕', '사전', '해석', '이슈', '효율', '분도', '드림', '앞서', '사유', '대략', '숫자', '기반', '파트', '반드시', '배경', '오류', '상승', '비중', '로만', '다소', '어필', '수기', '반면', '분류', '답안', '강조', '마케팅', '확보', '실질', '수집', '체감', '응답', '이외', '흐름', '완성', '보완', '형태', '증명', '등장', '엑셀', '만점', '취득']
#
# Cluster 17
# ['학교', '사용', '외부', '이용', '운영', '시설', '건물', '열람', '도서관', '센터', '장소', '무료', '공간', '개방', '통제', '출입', '부대', '로욜라', '마포', '기숙사', '정문', '폐쇄', '후문', '토모', '강의실']
#
# Cluster 18
# ['정도', '이번', '시작', '모두', '이상', '다음', '거의', '이후', '동안', '기간', '학원', '보통', '개월', '전부', '포함', '가능', '오후', '대신', '여행', '마무리', '기록', '정상', '최소', '나머지', '내내', '컴퓨터', '오전', '확률', '근황', '프로', '수술', '소식', '방학', '동시', '월급', '직전', '장님', '비용', '마감', '한지', '라인', '절반', '신분', '훈련', '인터뷰', '방송', '매년', '여름', '최대', '대출', '만원', '입대', '다음주', '시점', '종류', '추정', '외출', '책상', '빡세', '겨울', '종합', '차례', '당일', '금요일', '공사', '부산', '작업', '교환', '통보', '가량', '선수', '호텔', '명도', '중임', '페이', '졸업식', '배치', '남성', '출발', '이내', '월세', '차지', '토요일', '타임', '공연']
#
# Cluster 19
# ['코로나', '병원', '중국', '마스크', '진자', '감염', '검사', '지난', '발생', '지역', '일본', '바이러스', '조사', '치료', '환자', '의료', '국내', '경찰', '방역', '교회', '중국인', '증상', '격리', '우한', '전국', '진료', '대구', '확진', '접촉', '클럽', '이동', '신종', '자가', '주민', '수입', '폐렴', '입원', '입국', '주얼', '확산', '사망', '동선', '증가', '코로나바이러스', '판정', '음성', '이태원', '사망자', '왕준', '도시', '정관용']

# %% [markdown]
# - 0 : 교내이슈 + 19
# - 1 : 코로나
# - 2 : ?
# - 3 : 맛게
# - 4 : 대학평가
# - 5 : 가족
# - 6 : ?
# - 7 : 연애
# - 8 :법
# - 9 : 인간관계
# - 10 : 고시
# - 11 : 마음가짐(애매)
# - 12 : 취업준비(스펙)
# - 13 : 자격증(애매)
# - 14 : 학교시설
# - 15 : 애매
# - 16 : 커뮤니티
# - 17 : 정치 / 사회
# - 18 : 취업정보
# - 19 : 교내이슈

# %%
from sklearn.manifold import TSNE

# %%
new_word, new_idx, new_names = [], [], []
for i in range(len(idx)):
    if idx[i] == 0 or idx[i] == 1 or idx[i] == 4 or idx[i] == 14 or idx[i] == 18:
        continue
    else:
        new_names.append(names[i])
        new_word.append(word_vectors[i])
        new_idx.append(idx[i])
new_word = np.array(new_word)

# %%
tsne = TSNE(random_state = 0)

# word_vectors_tsne = tsne.fit_transform(new_word)
word_vectors_tsne = tsne.fit_transform(new_word)

# %%
plt.figure(figsize=(12,10))

plt.scatter(word_vectors_tsne[:, 0], word_vectors_tsne[:, 1], c=new_idx, s=10, cmap='viridis')

plt.xlabel('t-SNE 0')
plt.ylabel('t-SNE 1')

plt.show()

# %%
plt.figure(figsize=(12,10))

for i in range(len(word_vectors_tsne)):
    plt.text(word_vectors_tsne[i][0], word_vectors_tsne[i][1], str(new_idx[i]))

plt.xlim(word_vectors_tsne[:, 0].min(), word_vectors_tsne[:, 0].max())
plt.ylim(word_vectors_tsne[:, 1].min(), word_vectors_tsne[:, 1].max())

plt.xlabel('t-SNE 0')
plt.ylabel('t-SNE 1')

plt.show()

# %%
cluster_dict = {'2':'불만/요구사항','10':'교내이슈','17':'교내이슈','3':'고시','5':'인간관계','12':'인간관계', '6':'취업','9':'취업',
                '16':'취업', '7':'커뮤니티', '8':'맛게', '11':'대학평가','13':'가치관','15':'정치/사회','19':'정치/사회'}
cluster_map = {'2':9, '10':0, '17':0, '3': 1, '5':2, '12':2, '6':3, '9':3, '16':3, '7':4, '8':5, '11':6, '13':7, '15':8, '19':8}
temp = pd.DataFrame({'index': new_idx}).astype('str')
temp['cluster'] = temp['index'].replace(cluster_map)
temp['clustering'] = temp['index'].astype('str').replace(cluster_dict)
temp
# Out:
#      index  cluster clustering
# 0       13        7        가치관
# 1        5        2       인간관계
# 2       13        7        가치관
# 3        5        2       인간관계
# 4       13        7        가치관
# ...    ...      ...        ...
# 1316     5        2       인간관계
# 1317     2        9    불만/요구사항
# 1318     2        9    불만/요구사항
# 1319     6        3         취업
# 1320    19        8      정치/사회
#
# [1321 rows x 3 columns]

# %%
temp[['cluster','clustering']].drop_duplicates()
# Out:
#     cluster clustering
# 0         7        가치관
# 1         2       인간관계
# 6         0       교내이슈
# 7         4       커뮤니티
# 8         1         고시
# 12        6       대학평가
# 13        3         취업
# 21        8      정치/사회
# 39        5         맛게
# 47        9    불만/요구사항

# %%
len(set(temp['cluster'])), len(set(temp['clustering']))
# Out:
# (10, 10)

# %%
cluster_index = temp.cluster

# %%
plt.figure(figsize=(12,12))

colors = sns.color_palette(palette = 'hls', n_colors = 10)

for i in range(len(word_vectors_tsne)):
    plt.text(word_vectors_tsne[i][0], word_vectors_tsne[i][1], str(cluster_index[i]), color = colors[cluster_index[i]])

plt.xlim(word_vectors_tsne[:, 0].min(), word_vectors_tsne[:, 0].max())
plt.ylim(word_vectors_tsne[:, 1].min(), word_vectors_tsne[:, 1].max())

plt.xlabel('t-SNE 0')
plt.ylabel('t-SNE 1')

plt.savefig('시각화.png')

plt.show()
